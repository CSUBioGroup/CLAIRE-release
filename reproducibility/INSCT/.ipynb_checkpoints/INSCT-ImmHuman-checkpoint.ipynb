# %%
import os
import sys
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import scanpy as sc
import scipy.sparse as sps

from os.path import join
from pathlib import Path
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import sys
from pathlib import Path
from os.path import join
cur_dir = Path(os.getcwd())
sys.path.append(str(cur_dir.parent.parent.absolute()))
from tnn.tnn import *

from moco.kbet import calculate_kbet
from moco.utils import py_read_data, load_meta_txt
from moco.evaluation import scib_process 
from moco.prepare_dataset import prepare_dataset
from moco.preprocessing import preprocess_dataset
from scib_eval import scib_eval

data_dir = '/home/yxh/gitrepo/Batch-effect-removal-benchmarking-master/Script/sapling/GLOBE/data'
out_dir = '/home/yxh/gitrepo/Batch-effect-removal-benchmarking-master/Output'



# ================================
# prepare datasets
# ================================
dno = 'Pancreas'

n_hvgs = 2000
scale = False
batch_key = 'batchlb'
label_key = 'CellType'

dataset_dir = join(data_dir, dno)
sps_x, genes, cells, df_meta = prepare_dataset(dataset_dir)
X, cell_name, gene_name, df_meta = preprocess_dataset(
    sps_x, 
    cells, 
    genes, 
    df_meta, 
    n_hvgs, 
    scale, 
)

adata = sc.AnnData(X)
adata.var_names = gene_name
adata.obs = df_meta.copy()

sc.pp.scale(adata, max_value=None)
sc.tl.pca(adata, n_comps=50)

# repeat 
lr = 1e-3
log_dir = f'./outputs/{dno}-lr={lr}'
n_repeat = 1
for ri in range(n_repeat):
    os.makedirs(join(log_dir, f'results{ri+1}'), exist_ok=True)

    # training
    EPS = [2, 4, 10, 40, 80, 100]
    EMBS_INSCT = []
    RES_INSCT = None
    for ep in EPS:
        ad_ep = adata.copy()
        model = TNN(lr=lr, epochs=ep, n_epochs_without_progress=ep)  # default lr=1e-3
        model.fit(X = ad_ep, batch_name=batch_key)

        tmp_emb = model.transform(X = ad_ep)
        EMBS_INSCT.append(tmp_emb)

    # evaluation
    ADAS_INSCT = []
    for i, ep in enumerate(EPS):
        ad_tmp = sc.AnnData(EMBS_INSCT[i])
        ad_tmp.obs = df_meta.copy()
        ad_tmp.obsm["X_emb"] = ad_tmp.X
        ad_tmp.write(join(log_dir, f'results{ri+1}/ad_{ep}.h5ad'))
        ADAS_INSCT.append(ad_tmp)
        
        tmp_res = scib_eval(ad_tmp, batch_key, label_key)

        RES_INSCT = tmp_res if RES_INSCT is None else RES_INSCT.merge(tmp_res, left_index=True, right_index=True, how='inner')

    RES_INSCT.columns = EPS
    RES_INSCT.to_csv(join(log_dir, f'results{ri+1}/scib_eval.csv'), index=True)

    # Show plots
    # ================================
    fig2, axes = plt.subplots(len(EPS), 2, figsize=(16, 6*len(EPS)))
    for i, idx in enumerate(EPS):
        adata.obsm["X_tnn"] = EMBS_INSCT[i]

        sc.pl.embedding(adata, basis='tnn', color=[batch_key], show=False, ax=axes[i, 0])
        sc.pl.embedding(adata, basis='tnn', color=[label_key], show=False, ax=axes[i, 1])

        axes[i, 0].set_title(f'epoch={idx}')
        axes[i, 1].set_title(f'epoch={idx}')
        
    fig2.savefig(join(log_dir, f'results{ri+1}/umap.png'), facecolor='white')
# Out:
# The reading cost time 0.0415 secs
# preprocessing dataset, shape=(15558, 14767)
# ... storing 'batch' as categorical
# ... storing 'celltype_orig' as categorical
# ... storing 'celltype' as categorical
# /home/yxh/.local/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# version 0.0.2. 09:00, 12/01/2020
# Calculating MNNs...
# Processing datasets (0, 1)
# Processing datasets (0, 2)
# Processing datasets (0, 3)
# Processing datasets (0, 4)
# Processing datasets (1, 2)
# Processing datasets (1, 3)
# Processing datasets (1, 4)
# Processing datasets (2, 3)
# Processing datasets (2, 4)
# Processing datasets (3, 4)
# 12488 cells defined as MNNs
# Calculating KNNs...
# 2279 cells defined as KNNs
# Total cells for training:14767
# Reorder
# using learning rate  0.001
# Training neural network
# Epoch 1/2
# 231/231 [==============================] - 5s 10ms/step - loss: 0.8976
# Epoch 2/2
# 231/231 [==============================] - 2s 9ms/step - loss: 0.5062
# 462/462 [==============================] - 1s 1ms/step
# version 0.0.2. 09:00, 12/01/2020
# Calculating MNNs...
# Processing datasets (0, 1)
# Processing datasets (0, 2)
# Processing datasets (0, 3)
# Processing datasets (0, 4)
# Processing datasets (1, 2)
# Processing datasets (1, 3)
# Processing datasets (1, 4)
# Processing datasets (2, 3)
# Processing datasets (2, 4)
# Processing datasets (3, 4)
# 12519 cells defined as MNNs
# Calculating KNNs...
# 2248 cells defined as KNNs
# Total cells for training:14767
# Reorder
# using learning rate  0.001
# Training neural network
# Epoch 1/4
# 231/231 [==============================] - 3s 10ms/step - loss: 1.0015
# Epoch 2/4
# 231/231 [==============================] - 2s 10ms/step - loss: 0.5098
# Epoch 3/4
# 231/231 [==============================] - 3s 10ms/step - loss: 0.4415
# Epoch 4/4
# 231/231 [==============================] - 3s 11ms/step - loss: 0.4051
# 462/462 [==============================] - 1s 1ms/step
# version 0.0.2. 09:00, 12/01/2020
# Calculating MNNs...
# Processing datasets (0, 1)
# Processing datasets (0, 2)
# Processing datasets (0, 3)
# Processing datasets (0, 4)
# Processing datasets (1, 2)
# Processing datasets (1, 3)
# Processing datasets (1, 4)
# Processing datasets (2, 3)
# Processing datasets (2, 4)
# Processing datasets (3, 4)
# 12513 cells defined as MNNs
# Calculating KNNs...
# 2254 cells defined as KNNs
# Total cells for training:14767
# Reorder
# using learning rate  0.001
# Training neural network
# Epoch 1/10
# 231/231 [==============================] - 4s 8ms/step - loss: 0.8953
# Epoch 2/10
# 231/231 [==============================] - 2s 9ms/step - loss: 0.5243
# Epoch 3/10
# 231/231 [==============================] - 2s 9ms/step - loss: 0.4411
# Epoch 4/10
# 231/231 [==============================] - 2s 8ms/step - loss: 0.4097
# Epoch 5/10
# 231/231 [==============================] - 2s 8ms/step - loss: 0.3645
# Epoch 6/10
# 231/231 [==============================] - 2s 10ms/step - loss: 0.3442
# Epoch 7/10
# 231/231 [==============================] - 3s 10ms/step - loss: 0.3241
# Epoch 8/10
# 231/231 [==============================] - 3s 11ms/step - loss: 0.3127
# Epoch 9/10
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2970
# Epoch 10/10
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2946
# 462/462 [==============================] - 0s 690us/step
# version 0.0.2. 09:00, 12/01/2020
# Calculating MNNs...
# Processing datasets (0, 1)
# Processing datasets (0, 2)
# Processing datasets (0, 3)
# Processing datasets (0, 4)
# Processing datasets (1, 2)
# Processing datasets (1, 3)
# Processing datasets (1, 4)
# Processing datasets (2, 3)
# Processing datasets (2, 4)
# Processing datasets (3, 4)
# 12515 cells defined as MNNs
# Calculating KNNs...
# 2252 cells defined as KNNs
# Total cells for training:14767
# Reorder
# using learning rate  0.001
# Training neural network
# Epoch 1/40
# 231/231 [==============================] - 3s 10ms/step - loss: 0.9910
# Epoch 2/40
# 231/231 [==============================] - 3s 11ms/step - loss: 0.5222
# Epoch 3/40
# 231/231 [==============================] - 3s 11ms/step - loss: 0.4521
# Epoch 4/40
# 231/231 [==============================] - 2s 10ms/step - loss: 0.4241
# Epoch 5/40
# 231/231 [==============================] - 2s 10ms/step - loss: 0.3930
# Epoch 6/40
# 231/231 [==============================] - 2s 10ms/step - loss: 0.3630
# Epoch 7/40
# 231/231 [==============================] - 3s 11ms/step - loss: 0.3382
# Epoch 8/40
# 231/231 [==============================] - 3s 11ms/step - loss: 0.3268
# Epoch 9/40
# 231/231 [==============================] - 3s 11ms/step - loss: 0.3064
# Epoch 10/40
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2990
# Epoch 11/40
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2978
# Epoch 12/40
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2781
# Epoch 13/40
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2710
# Epoch 14/40
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2665
# Epoch 15/40
# 231/231 [==============================] - 2s 9ms/step - loss: 0.2790
# Epoch 16/40
# 231/231 [==============================] - 2s 8ms/step - loss: 0.2653
# Epoch 17/40
# 231/231 [==============================] - 2s 8ms/step - loss: 0.2559
# Epoch 18/40
# 231/231 [==============================] - 2s 9ms/step - loss: 0.2606
# Epoch 19/40
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2518
# Epoch 20/40
# 231/231 [==============================] - 2s 8ms/step - loss: 0.2454
# Epoch 21/40
# 231/231 [==============================] - 2s 8ms/step - loss: 0.2408
# Epoch 22/40
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2518
# Epoch 23/40
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2397
# Epoch 24/40
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2448
# Epoch 25/40
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2389
# Epoch 26/40
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2381
# Epoch 27/40
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2376
# Epoch 28/40
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2341
# Epoch 29/40
# 231/231 [==============================] - 2s 9ms/step - loss: 0.2355
# Epoch 30/40
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2248
# Epoch 31/40
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2292
# Epoch 32/40
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2341
# Epoch 33/40
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2216
# Epoch 34/40
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2248
# Epoch 35/40
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2227
# Epoch 36/40
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2216
# Epoch 37/40
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2215
# Epoch 38/40
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2236
# Epoch 39/40
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2228
# Epoch 40/40
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2155
# 462/462 [==============================] - 1s 1ms/step
# version 0.0.2. 09:00, 12/01/2020
# Calculating MNNs...
# Processing datasets (0, 1)
# Processing datasets (0, 2)
# Processing datasets (0, 3)
# Processing datasets (0, 4)
# Processing datasets (1, 2)
# Processing datasets (1, 3)
# Processing datasets (1, 4)
# Processing datasets (2, 3)
# Processing datasets (2, 4)
# Processing datasets (3, 4)
# 12513 cells defined as MNNs
# Calculating KNNs...
# 2254 cells defined as KNNs
# Total cells for training:14767
# Reorder
# using learning rate  0.001
# Training neural network
# Epoch 1/80
# 231/231 [==============================] - 3s 8ms/step - loss: 0.9548
# Epoch 2/80
# 231/231 [==============================] - 2s 10ms/step - loss: 0.5033
# Epoch 3/80
# 231/231 [==============================] - 2s 9ms/step - loss: 0.4226
# Epoch 4/80
# 231/231 [==============================] - 2s 9ms/step - loss: 0.3893
# Epoch 5/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.3547
# Epoch 6/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.3396
# Epoch 7/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.3343
# Epoch 8/80
# 231/231 [==============================] - 3s 10ms/step - loss: 0.3114
# Epoch 9/80
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2998
# Epoch 10/80
# 231/231 [==============================] - 2s 10ms/step - loss: 0.3066
# Epoch 11/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2916
# Epoch 12/80
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2831
# Epoch 13/80
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2856
# Epoch 14/80
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2813
# Epoch 15/80
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2795
# Epoch 16/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2654
# Epoch 17/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2690
# Epoch 18/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2673
# Epoch 19/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2580
# Epoch 20/80
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2592
# Epoch 21/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2591
# Epoch 22/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2479
# Epoch 23/80
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2599
# Epoch 24/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2467
# Epoch 25/80
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2473
# Epoch 26/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2434
# Epoch 27/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2385
# Epoch 28/80
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2386
# Epoch 29/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2425
# Epoch 30/80
# 231/231 [==============================] - 2s 7ms/step - loss: 0.2375
# Epoch 31/80
# 231/231 [==============================] - 2s 8ms/step - loss: 0.2385
# Epoch 32/80
# 231/231 [==============================] - 2s 7ms/step - loss: 0.2398
# Epoch 33/80
# 231/231 [==============================] - 2s 8ms/step - loss: 0.2340
# Epoch 34/80
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2368
# Epoch 35/80
# 231/231 [==============================] - 2s 8ms/step - loss: 0.2351
# Epoch 36/80
# 231/231 [==============================] - 2s 8ms/step - loss: 0.2322
# Epoch 37/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2241
# Epoch 38/80
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2335
# Epoch 39/80
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2265
# Epoch 40/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2230
# Epoch 41/80
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2237
# Epoch 42/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2202
# Epoch 43/80
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2157
# Epoch 44/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2210
# Epoch 45/80
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2185
# Epoch 46/80
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2179
# Epoch 47/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2227
# Epoch 48/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2043
# Epoch 49/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2189
# Epoch 50/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2187
# Epoch 51/80
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2099
# Epoch 52/80
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2117
# Epoch 53/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2148
# Epoch 54/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2174
# Epoch 55/80
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2142
# Epoch 56/80
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2186
# Epoch 57/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2115
# Epoch 58/80
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2044
# Epoch 59/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2052
# Epoch 60/80
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2103
# Epoch 61/80
# 231/231 [==============================] - 2s 7ms/step - loss: 0.2061
# Epoch 62/80
# 231/231 [==============================] - 2s 8ms/step - loss: 0.2082
# Epoch 63/80
# 231/231 [==============================] - 2s 6ms/step - loss: 0.2073
# Epoch 64/80
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2156
# Epoch 65/80
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2014
# Epoch 66/80
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2048
# Epoch 67/80
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2066
# Epoch 68/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2087
# Epoch 69/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2010
# Epoch 70/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2012
# Epoch 71/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.1996
# Epoch 72/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2078
# Epoch 73/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2098
# Epoch 74/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.1922
# Epoch 75/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.1978
# Epoch 76/80
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2060
# Epoch 77/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.1998
# Epoch 78/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2002
# Epoch 79/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.1990
# Epoch 80/80
# 231/231 [==============================] - 3s 11ms/step - loss: 0.1993
# 462/462 [==============================] - 1s 1ms/step
# version 0.0.2. 09:00, 12/01/2020
# Calculating MNNs...
# Processing datasets (0, 1)
# Processing datasets (0, 2)
# Processing datasets (0, 3)
# Processing datasets (0, 4)
# Processing datasets (1, 2)
# Processing datasets (1, 3)
# Processing datasets (1, 4)
# Processing datasets (2, 3)
# Processing datasets (2, 4)
# Processing datasets (3, 4)
# 12520 cells defined as MNNs
# Calculating KNNs...
# 2247 cells defined as KNNs
# Total cells for training:14767
# Reorder
# using learning rate  0.001
# Training neural network
# Epoch 1/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.8912
# Epoch 2/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.5026
# Epoch 3/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.4212
# Epoch 4/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.3787
# Epoch 5/100
# 231/231 [==============================] - 3s 10ms/step - loss: 0.3447
# Epoch 6/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.3396
# Epoch 7/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.3198
# Epoch 8/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.3109
# Epoch 9/100
# 231/231 [==============================] - 3s 12ms/step - loss: 0.2998
# Epoch 10/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2987
# Epoch 11/100
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2857
# Epoch 12/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2859
# Epoch 13/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2844
# Epoch 14/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2725
# Epoch 15/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2670
# Epoch 16/100
# 231/231 [==============================] - 2s 9ms/step - loss: 0.2675
# Epoch 17/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2651
# Epoch 18/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2556
# Epoch 19/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2554
# Epoch 20/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2551
# Epoch 21/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2502
# Epoch 22/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2458
# Epoch 23/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2472
# Epoch 24/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2410
# Epoch 25/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2451
# Epoch 26/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2405
# Epoch 27/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2425
# Epoch 28/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2395
# Epoch 29/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2319
# Epoch 30/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2295
# Epoch 31/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2346
# Epoch 32/100
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2309
# Epoch 33/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2361
# Epoch 34/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2307
# Epoch 35/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2324
# Epoch 36/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2322
# Epoch 37/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2340
# Epoch 38/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2274
# Epoch 39/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2220
# Epoch 40/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2215
# Epoch 41/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2153
# Epoch 42/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2302
# Epoch 43/100
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2248
# Epoch 44/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2210
# Epoch 45/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2244
# Epoch 46/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2189
# Epoch 47/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2176
# Epoch 48/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2194
# Epoch 49/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2235
# Epoch 50/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2193
# Epoch 51/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2150
# Epoch 52/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2136
# Epoch 53/100
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2122
# Epoch 54/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2158
# Epoch 55/100
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2111
# Epoch 56/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2125
# Epoch 57/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2124
# Epoch 58/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2082
# Epoch 59/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2204
# Epoch 60/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2095
# Epoch 61/100
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2041
# Epoch 62/100
# 231/231 [==============================] - 2s 10ms/step - loss: 0.2188
# Epoch 63/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2098
# Epoch 64/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2125
# Epoch 65/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2089
# Epoch 66/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2035
# Epoch 67/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.1999
# Epoch 68/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2165
# Epoch 69/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2086
# Epoch 70/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2089
# Epoch 71/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2061
# Epoch 72/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2139
# Epoch 73/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2109
# Epoch 74/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2039
# Epoch 75/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2083
# Epoch 76/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2033
# Epoch 77/100
# 231/231 [==============================] - 3s 10ms/step - loss: 0.2051
# Epoch 78/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2005
# Epoch 79/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2004
# Epoch 80/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2026
# Epoch 81/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2051
# Epoch 82/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2042
# Epoch 83/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.1975
# Epoch 84/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2034
# Epoch 85/100
# 231/231 [==============================] - 3s 12ms/step - loss: 0.2016
# Epoch 86/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2007
# Epoch 87/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.1985
# Epoch 88/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2044
# Epoch 89/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.1993
# Epoch 90/100
# 231/231 [==============================] - 3s 10ms/step - loss: 0.1973
# Epoch 91/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2028
# Epoch 92/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2027
# Epoch 93/100
# 231/231 [==============================] - 3s 10ms/step - loss: 0.1956
# Epoch 94/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2063
# Epoch 95/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2015
# Epoch 96/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.2059
# Epoch 97/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.1927
# Epoch 98/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.1924
# Epoch 99/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.1949
# Epoch 100/100
# 231/231 [==============================] - 3s 11ms/step - loss: 0.1996
# 462/462 [==============================] - 1s 1ms/step
# NMI...
# ARI...
# Silhouette score...
# Calculating kbet...
# NMI...
# ARI...
# Silhouette score...
# Calculating kbet...
# NMI...
# ARI...
# Silhouette score...
# Calculating kbet...
# NMI...
# ARI...
# Silhouette score...
# Calculating kbet...
# NMI...
# ARI...
# Silhouette score...
# Calculating kbet...
# NMI...
# ARI...
# Silhouette score...
# Calculating kbet...

# %%
plt.plot(model.loss_history_)

# %%
RES_INSCT
# Out:
#                                 2         4         10        40        80   \
# NMI_cluster/label          0.680533  0.694113  0.724686  0.722817  0.737971
# ARI_cluster/label          0.474850  0.546457  0.532387  0.468192  0.480208
# ASW_label                  0.712390  0.676880  0.628188  0.656866  0.562465
# ASW_label/batch            0.738168  0.710886  0.671223  0.693357  0.708789
# isolated_label_F1               NaN       NaN       NaN       NaN       NaN
# isolated_label_silhouette       NaN       NaN       NaN       NaN       NaN
# graph_conn                      NaN       NaN       NaN       NaN       NaN
# trajectory                      NaN       NaN       NaN       NaN       NaN
# kBET                       0.400149  0.477890  0.441593  0.442405  0.394935
#
#                                 100
# NMI_cluster/label          0.730490
# ARI_cluster/label          0.525678
# ASW_label                  0.595094
# ASW_label/batch            0.683028
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                      NaN
# trajectory                      NaN
# kBET                       0.388027

# %%
fig2
