# %%
import os
import sys
import datetime
import scanorama
import numpy as np
import pandas as pd
import scanpy as sc
import scipy.sparse as sps
import matplotlib.pyplot as plt

from pathlib import Path
from os.path import join
from functools import reduce
from sklearn.metrics import pairwise_distances

sc.settings.verbosity = 0             # verbosity: errors (0), warnings (1), info (2), hints (3)
#sc.logging.print_versions()

sc.settings.set_figure_params(dpi=80)
# %matplotlib inline

dno = 'lung'
data_dir = join('/home/yxh/gitrepo/Batch-effect-removal-benchmarking-master/Data', dno)
out_dir  = join('/home/yxh/gitrepo/Batch-effect-removal-benchmarking-master/Output', dno)

sc.settings.set_figure_params(dpi=80)
sc.settings.figdir = Path(f'/home/yxh/gitrepo/Batch-effect-removal-benchmarking-master/Output/{dno}/scanorama')
sc.settings.figdir.mkdir(parents=True, exist_ok=True)


min_cells = 3
npcs = 50
sf = 1e4
n_hvgs = 2000
n_neighs = 15

batch_key = 'batch'
label_key = 'cell_type'

adata = sc.read_h5ad(join(data_dir, 'Lung_atlas_public.h5ad'))  # normalized data

sc.pp.highly_variable_genes(adata, n_top_genes= n_hvgs, 
#                             min_mean=0.0125, max_mean=3, min_disp=0.5,
                            batch_key=batch_key)

adata = adata[:, adata.var.highly_variable].copy()
# sc.pp.scale(adata, max_value=None)

# split by batch
Xs = []
for bi in adata.obs.batch.unique():
    cell_bi = adata.obs.batch == bi
    adata_batch = adata[cell_bi].copy()
    sc.pp.scale(adata_batch)

    Xs.append(adata_batch)
    print(f'n of {bi} = {cell_bi.sum()}, {len(Xs[-1])}')

corrected = scanorama.correct_scanpy(Xs, return_dimred=True, dimred=npcs)

ada_sca = sc.concat(corrected)
ada_sca.obsm["X_emb"] = ada_sca.obsm['X_scanorama']

from evaluation import scib_process
ada_sca.obs[[batch_key, label_key]] = ada_sca.obs[[batch_key, label_key]].astype('category')

tmp_res = scib_process(ada_sca,
                        batch_key=batch_key,
                        label_key=label_key,
                        nmi_=True, nmi_method='arithmetic', save_nmi=None,
                        ari_=True,
                        silhouette_=True, si_metric='euclidean',
                        # pcr_=pcr_,
                        # cell_cycle_=cell_cycle_, organism=organism,
                        isolated_labels_=False, n_isolated=None,
                        graph_conn_=True,
                        type_='emb',
                        subsample=0.5,  # for kBET
                        kBET_ = False,   
                        clisi_= False,
                        ilisi_= False)

tmp_res.to_csv(join(out_dir,  f'scanorama/{dno}_emb_eval.csv'), index=True, sep=',')
# Out:
# /home/yxh/.local/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# n of B1 = 2140, 2140
# n of B2 = 3297, 3297
# n of B3 = 1911, 1911
# n of B4 = 2353, 2353
# n of A6 = 2410, 2410
# n of A1 = 1845, 1845
# n of A5 = 2406, 2406
# n of A3 = 1226, 1226
# n of A4 = 705, 705
# n of A2 = 1454, 1454
# n of 5 = 2379, 2379
# n of 2 = 1988, 1988
# n of 4 = 3763, 3763
# n of 3 = 462, 462
# n of 1 = 904, 904
# n of 6 = 3229, 3229
# Found 2000 genes among all datasets
# [[0.00000000e+00 8.03271028e-01 2.01988488e-01 2.37994050e-01
#   2.38317757e-02 1.16822430e-02 1.63551402e-02 1.63132137e-03
#   2.83687943e-03 4.81430536e-03 2.13114754e-01 5.13078471e-02
#   1.21962617e-01 2.20779221e-01 3.65044248e-02 6.25580675e-02]
#  [0.00000000e+00 0.00000000e+00 3.83045526e-01 2.55843604e-01
#   5.14522822e-02 9.21409214e-03 2.09281165e-02 0.00000000e+00
#   2.83687943e-03 3.03306036e-03 4.62799496e-01 1.12676056e-01
#   2.20834441e-01 2.57575758e-01 6.74778761e-02 1.33477857e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 4.17059131e-01
#   1.90871369e-02 1.15122972e-02 7.32600733e-03 8.15660685e-04
#   2.83687943e-03 2.06327373e-03 3.96805380e-01 3.54627767e-01
#   4.08163265e-02 1.32034632e-01 3.66150442e-01 1.72684458e-02]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   2.24066390e-02 1.78861789e-02 7.48129676e-03 1.63132137e-03
#   5.67375887e-03 1.37551582e-03 1.60992013e-01 1.46378270e-01
#   2.76243094e-02 3.22510823e-01 1.64823009e-01 1.82719108e-02]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 8.48238482e-01 4.82959268e-01 6.55791191e-01
#   5.54609929e-01 5.08253095e-01 3.36275746e-03 0.00000000e+00
#   2.12596333e-03 2.16450216e-03 0.00000000e+00 1.24481328e-03]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 4.35772358e-01 6.97389886e-01
#   7.84397163e-01 8.06740028e-01 2.16802168e-03 5.42005420e-04
#   1.62601626e-03 1.08225108e-02 0.00000000e+00 1.62601626e-03]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 2.68352365e-01
#   4.96453901e-01 4.38101788e-01 1.28844555e-02 1.00603622e-03
#   2.82626766e-02 4.11255411e-02 2.21238938e-03 1.24688279e-03]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   7.00709220e-01 5.99037139e-01 2.94241278e-03 8.15660685e-04
#   2.12596333e-03 0.00000000e+00 2.21238938e-03 1.63132137e-03]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 8.39716312e-01 9.92907801e-03 5.67375887e-03
#   1.41843972e-02 1.73160173e-02 4.25531915e-03 2.83687943e-03]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 1.92572215e-02 1.03163686e-02
#   1.65061898e-02 4.11255411e-02 5.53097345e-03 8.67141530e-03]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 5.70422535e-01
#   5.19546028e-01 6.08225108e-01 5.40929204e-01 4.57335015e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   1.94668008e-01 2.68398268e-01 5.57522124e-01 1.83098592e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 3.96103896e-01 1.07300885e-01 6.91235677e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 2.22943723e-01 2.79220779e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 2.36725664e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]]
# Processing datasets (4, 5)
# Processing datasets (8, 9)
# Processing datasets (5, 9)
# Processing datasets (0, 1)
# Processing datasets (5, 8)
# Processing datasets (7, 8)
# Processing datasets (5, 7)
# Processing datasets (12, 15)
# Processing datasets (4, 7)
# Processing datasets (10, 13)
# Processing datasets (7, 9)
# Processing datasets (10, 11)
# Processing datasets (11, 14)
# Processing datasets (4, 8)
# Processing datasets (10, 14)
# Processing datasets (10, 12)
# Processing datasets (4, 9)
# Processing datasets (6, 8)
# Processing datasets (4, 6)
# Processing datasets (1, 10)
# Processing datasets (10, 15)
# Processing datasets (6, 9)
# Processing datasets (5, 6)
# Processing datasets (2, 3)
# Processing datasets (2, 10)
# Processing datasets (12, 13)
# Processing datasets (1, 2)
# Processing datasets (2, 14)
# Processing datasets (2, 11)
# Processing datasets (3, 13)
# Processing datasets (13, 15)
# Processing datasets (11, 13)
# Processing datasets (6, 7)
# Processing datasets (1, 13)
# Processing datasets (1, 3)
# Processing datasets (0, 3)
# Processing datasets (14, 15)
# Processing datasets (13, 14)
# Processing datasets (1, 12)
# Processing datasets (0, 13)
# Processing datasets (0, 10)
# Processing datasets (0, 2)
# Processing datasets (11, 12)
# Processing datasets (11, 15)
# Processing datasets (3, 14)
# Processing datasets (3, 10)
# Processing datasets (3, 11)
# Processing datasets (1, 15)
# Processing datasets (2, 13)
# Processing datasets (0, 12)
# Processing datasets (1, 11)
# Processing datasets (12, 14)
# NMI...
# ARI...
# Silhouette score...
# Graph connectivity...

# %%
sc.pp.neighbors(ada_sca, n_neighbors=n_neighs, use_rep='X_scanorama') # use raw.X    
sc.tl.umap(ada_sca)
sc.pl.umap(ada_sca, color=[batch_key, label_key])

os.makedirs(join(out_dir, 'scanorama/h5ad'), exist_ok=True)
ada_sca.write(join(out_dir, f'scanorama/h5ad/{dno}_emb.h5ad'))
# Out:
# ... storing 'dataset' as categorical
# ... storing 'location' as categorical
# ... storing 'patientGroup' as categorical
# ... storing 'protocol' as categorical
# ... storing 'sanger_type' as categorical
# ... storing 'sampling_method' as categorical
# ... storing 'donor' as categorical
